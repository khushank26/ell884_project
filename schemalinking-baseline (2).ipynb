# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
##Saving the baseline model
import json
import torch
from datasets import Dataset
from transformers import T5Tokenizer, T5ForConditionalGeneration
from torch.optim import AdamW
from torch.utils.data import DataLoader
from peft import get_peft_model, LoraConfig, TaskType
from tqdm import tqdm
# Setup
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load Data
with open("/kaggle/input/spiderdatasetnlp/spider_data/train_spider.json", "r") as f:
    train_data = json.load(f)

with open("/kaggle/input/spiderdatasetnlp/spider_data/tables.json", "r") as f:
    tables_data = json.load(f)


db_schemas = {}
for db in tables_data:
    db_id = db["db_id"]
    table_names = db["table_names_original"]
    column_names = db["column_names_original"]

    table_to_columns = {table: [] for table in table_names}
    for table_idx, column_name in column_names:
        if table_idx == -1:
            continue
        table = table_names[table_idx]
        table_to_columns[table].append(column_name)

    db_schemas[db_id] = table_to_columns

#train_data = train_data[:500]


input_texts = []
output_texts = []

for item in train_data:
    db_id = item['db_id']
    question = item['question']
    sql = item['query']
    db_schema = db_schemas[db_id]


    schema_str = "\n".join(f"- {t}: {', '.join(cols)}" for t, cols in db_schema.items())

    input_text = f"""


    Database Schema:
    {schema_str}
    
    Question:
    {question}
    
    Provide SQL Query: 
    """


    output_text = sql

    input_texts.append(input_text)
    output_texts.append(output_text)

    # print(f"OUTPUT : {output_text}")

dataset = Dataset.from_dict({
    "input_text": input_texts,
    "output_text": output_texts
})

tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")

def tokenize_function(examples):
    model_inputs = tokenizer(examples["input_text"], max_length=512, padding="max_length", truncation=True)
    labels = tokenizer(examples["output_text"], max_length=128, padding="max_length", truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(tokenize_function, batched=True, remove_columns=["input_text", "output_text"])

train_dataloader = DataLoader(
    tokenized_dataset,
    batch_size=4,
    shuffle=True,
    collate_fn=lambda x: {
        key: torch.tensor([d[key] for d in x]) for key in x[0]
    }
)
# Model
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")
peft_config = LoraConfig(task_type=TaskType.SEQ_2_SEQ_LM, inference_mode=False, r=16, lora_alpha=32, lora_dropout=0.1)
model = get_peft_model(model, peft_config)
model.to(device)

optimizer = AdamW(model.parameters(), lr=5e-4)

# Training
model.train()
for epoch in range(5):
    total_loss = 0
    for batch in tqdm(train_dataloader,desc="train:"):
        optimizer.zero_grad()
        batch = {k: v.to(device) for k, v in batch.items()}
    
        outputs = model(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            labels=batch["labels"]
        )
        loss = outputs.loss
        loss.backward()
        optimizer.step()
    
        total_loss += loss.item()

    avg_loss = total_loss / len(train_dataloader)
    print(f"Epoch {epoch+1} - Average Training Loss: {avg_loss:.4f}")

# Save
model.save_pretrained("./model_output")
tokenizer.save_pretrained("./model_output")
# Out:
# Map:   0%|          | 0/7000 [00:00<?, ? examples/s]
# train:: 100%|██████████| 1750/1750 [16:07<00:00,  1.81it/s]
# Epoch 1 - Average Training Loss: 1.0602
# train:: 100%|██████████| 1750/1750 [16:05<00:00,  1.81it/s]
# Epoch 2 - Average Training Loss: 0.1780
# train:: 100%|██████████| 1750/1750 [16:06<00:00,  1.81it/s]
# Epoch 3 - Average Training Loss: 0.1412
# train:: 100%|██████████| 1750/1750 [16:06<00:00,  1.81it/s]
# Epoch 4 - Average Training Loss: 0.1213
# train:: 100%|██████████| 1750/1750 [16:07<00:00,  1.81it/s]
# Epoch 5 - Average Training Loss: 0.1182
# ('./model_output/tokenizer_config.json',
#  './model_output/special_tokens_map.json',
#  './model_output/spiece.model',
#  './model_output/added_tokens.json')

# %%
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer
from peft import PeftModel
import json

# Setup
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load LLM1 (Table Selector)
llm1_tokenizer = T5Tokenizer.from_pretrained("/kaggle/input/llm1_schemalinking/pytorch/default/1/llm1_schemalinking/model_output")
llm1_model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")
llm1_model = PeftModel.from_pretrained(llm1_model, "/kaggle/input/llm1_schemalinking/pytorch/default/1/llm1_schemalinking/model_output")
llm1_model.to(device)
llm1_model.eval()

# Load LLM2 (SQL Generator)
llm2_tokenizer = T5Tokenizer.from_pretrained("/kaggle/working/model_output")
llm2_model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")
llm2_model = PeftModel.from_pretrained(llm2_model, "/kaggle/working/model_output")
llm2_model.to(device)
llm2_model.eval()

# Load schema
with open("/kaggle/input/spiderdatasetnlp/spider_data/tables.json", "r") as f:
    tables_data = json.load(f)

db_schemas = {}
for db in tables_data:
    db_id = db["db_id"]
    table_names = db["table_names_original"]
    column_names = db["column_names_original"]

    table_to_columns = {table: [] for table in table_names}
    for table_idx, column_name in column_names:
        if table_idx == -1:
            continue
        table = table_names[table_idx]
        table_to_columns[table].append(column_name)

    db_schemas[db_id] = table_to_columns

# ---------- Pipeline Inference ---------- #

def get_relevant_tables(question, db_schema):
    """Uses LLM1 to get relevant tables."""
    schema_str = "\n".join(f"- {t}: {', '.join(cols)}" for t, cols in db_schema.items())
    input_text = f"""
Database Schema:
{schema_str}

Question:
{question}

Which tables are relevant?"""

    inputs = llm1_tokenizer(input_text, return_tensors="pt", truncation=True, padding=True).to(device)
    outputs = llm1_model.generate(**inputs, max_new_tokens=64)
    prediction = llm1_tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    # Parse table flags (e.g., "Tables: students -> True, courses -> False")
    table_flags = {}
    for part in prediction.split(","):
        if "->" in part:
            table, flag = part.strip().split("->")
            table_flags[table.strip()] = flag.strip().lower() == "true"
    return [table for table, is_used in table_flags.items() if is_used]

def generate_sql(question, reduced_schema):
    """Uses LLM2 to generate SQL from question and pruned schema."""
    schema_str = "\n".join(f"- {t}: {', '.join(cols)}" for t, cols in reduced_schema.items())
    input_text = f"""

Database Schema:
{schema_str}

Question:
{question}

Provide SQL Query:"""

    inputs = llm2_tokenizer(input_text, return_tensors="pt", truncation=True, padding=True).to(device)
    outputs = llm2_model.generate(**inputs, max_new_tokens=128)
    return llm2_tokenizer.decode(outputs[0], skip_special_tokens=True)

# ---------- Run Example ---------- #
def run_pipeline(question, db_id):
    full_schema = db_schemas[db_id]
    relevant_tables = get_relevant_tables(question, full_schema)

    if not relevant_tables:
        return "No relevant tables found."

    reduced_schema = {}
    for t in relevant_tables:
        t_clean = t.lower().replace("tables:", "").replace("table:", "").strip()
        if t_clean in full_schema:
            reduced_schema[t_clean] = full_schema[t_clean]

    sql = generate_sql(question, reduced_schema)
    return sql

# %%
import torch
import json
from tqdm import tqdm
from datasets import Dataset
from torch.utils.data import DataLoader
from transformers import T5ForConditionalGeneration, T5Tokenizer
from peft import PeftModel

# Setup
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load LLM1 (table selector)
llm1_tokenizer = T5Tokenizer.from_pretrained("/kaggle/input/llm1_schemalinking/pytorch/default/1/llm1_schemalinking/model_output")
llm1_base = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")
llm1_model = PeftModel.from_pretrained(llm1_base, "/kaggle/input/llm1_schemalinking/pytorch/default/1/llm1_schemalinking/model_output")
llm1_model.to(device)
llm1_model.eval()

# Load LLM2 (SQL generator)
tokenizer = T5Tokenizer.from_pretrained("/kaggle/working/model_output")
base_model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")
model = PeftModel.from_pretrained(base_model, "/kaggle/working/model_output")
model.to(device)
model.eval()

# Load validation data
with open("/kaggle/input/spiderdatasetnlp/spider_data/dev.json", "r") as f:
    val_data = json.load(f)

#val_data = val_data[:100]

with open("/kaggle/input/spiderdatasetnlp/spider_data/tables.json", "r") as f:
    tables_data = json.load(f)

# Build schema dictionary
db_schemas = {}
for db in tables_data:
    db_id = db["db_id"]
    table_names = db["table_names_original"]
    column_names = db["column_names_original"]

    table_to_columns = {table: [] for table in table_names}
    for table_idx, column_name in column_names:
        if table_idx == -1:
            continue
        table = table_names[table_idx]
        table_to_columns[table].append(column_name)

    db_schemas[db_id] = table_to_columns

# Helper: get relevant tables using LLM1
def get_relevant_tables(question, db_schema):
    schema_str = "\n".join(f"- {t}: {', '.join(cols)}" for t, cols in db_schema.items())
    input_text = f"""
Database Schema:
{schema_str}

Question:
{question}

In case of JOIN consider all tables to be relevant

Which tables are relevant? """

    inputs = llm1_tokenizer(input_text, return_tensors="pt", truncation=True, padding=True).to(device)
    outputs = llm1_model.generate(**inputs, max_new_tokens=64)
    prediction = llm1_tokenizer.decode(outputs[0], skip_special_tokens=True)

    table_flags = {}
    for part in prediction.split(","):
        if "->" in part:
            table, flag = part.strip().split("->")
            table_flags[table.strip()] = flag.strip().lower() == "true"
    return [table for table, is_used in table_flags.items() if is_used]

# Preprocessing: Generate input_texts and output_texts using integrated pipeline
input_texts = []
output_texts = []
db_ids = []

for item in tqdm(val_data, desc="Preparing data"):
    db_id = item['db_id']
    question = item['question']
    gold_sql = item['query']
    full_schema = db_schemas[db_id]

    # LLM1: Select relevant tables
    relevant_tables = get_relevant_tables(question, full_schema)
    if not relevant_tables:
        reduced_schema = full_schema  # fallback to full
    else:
        reduced_schema = {}
        for t in relevant_tables:
            t_clean = t.lower().replace("tables:", "").replace("table:", "").strip()
            if t_clean in full_schema:
                reduced_schema[t_clean] = full_schema[t_clean]


    schema_str = "\n".join(f"- {t}: {', '.join(cols)}" for t, cols in reduced_schema.items())
    input_text = f"Database Schema:\n{schema_str}\n\nQuestion:\n{question}\n\nProvide SQL Query:"

    input_texts.append(input_text)
    output_texts.append(gold_sql)
    db_ids.append(db_id)

# Hugging Face dataset
dataset = Dataset.from_dict({
    "input_text": input_texts,
    "output_text": output_texts
})

# Tokenization
def tokenize_function(examples):
    model_inputs = tokenizer(examples["input_text"], max_length=512, padding="max_length", truncation=True)
    labels = tokenizer(examples["output_text"], max_length=128, padding="max_length", truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(tokenize_function, batched=True, remove_columns=["input_text", "output_text"])

val_dataloader = DataLoader(
    tokenized_dataset,
    batch_size=4,
    collate_fn=lambda x: {
        key: torch.tensor([d[key] for d in x]) for key in x[0]
    }
)

# Evaluation
preds = []
labels = []

for batch in tqdm(val_dataloader, desc="Evaluating"):
    batch = {k: v.to(device) for k, v in batch.items()}

    with torch.no_grad():
        generated_ids = model.generate(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            num_beams=5,
            early_stopping=False,
            max_length=128
        )

    decoded_preds = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(batch["labels"], skip_special_tokens=True)

    preds.extend(decoded_preds)
    labels.extend(decoded_labels)

# Output JSON for evaluation
prediction_entries = []
for pred, gold, db_id in zip(preds, labels, db_ids):
    prediction_entries.append({
        "query": pred,
        "db_id": db_id
    })

with open("predict.json", "w") as f:
    json.dump(prediction_entries, f, indent=2)

print("✅ Saved predictions to predict.json")
# Out:
# Preparing data: 100%|██████████| 1034/1034 [22:19<00:00,  1.30s/it]
# Map:   0%|          | 0/1034 [00:00<?, ? examples/s]
# Evaluating: 100%|██████████| 259/259 [10:59<00:00,  2.55s/it]
# ✅ Saved predictions to predict.json

# %%
import json

# Load gold data from Spider dev.json
with open("/kaggle/input/spiderdatasetnlp/spider_data/dev.json") as f:
    gold_data = json.load(f)

# Write gold.sql (each line: <GOLD_SQL> \t <DB_ID>)
with open("gold.sql", "w") as f:
    for example in gold_data:
        f.write(f"{example['query']}\t{example['db_id']}\n")

# Write pred.sql (each line: predicted SQL)
# `preds` must be in the same order as `gold_data`
with open("pred.sql", "w") as f:
    for pred in preds:
        f.write(pred.strip() + "\n")

# %%
# !git clone https://github.com/taoyds/spider.git
# Out:
# Cloning into 'spider'...
# remote: Enumerating objects: 386, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 386 (delta 18), reused 15 (delta 13), pack-reused 356 (from 1)
# Receiving objects: 100% (386/386), 44.93 MiB | 38.24 MiB/s, done.
# Resolving deltas: 100% (112/112), done.

# %%
# !python3 /kaggle/working/spider/evaluation.py \
    --gold gold.sql \
    --pred pred.sql \
    --etype match \
    --db /kaggle/input/spiderdatasetnlp/spider_data/database \
    --table /kaggle/input/spiderdatasetnlp/spider_data/tables.json
# Out:
# medium pred: SELECT T1.Name , T1.Country , T1.Age FROM singer AS T1 JOIN singer AS T2 ON T1.Singer_ID = T2.Singer_ID ORDER BY T2.Age DESC
# medium gold: SELECT name ,  country ,  age FROM singer ORDER BY age DESC
#
# medium pred: SELECT T2.Song_Name , T2.Song_release_year FROM singer AS T1 JOIN singer AS T2 ON T1.Singer_ID = T2.Singer_ID ORDER BY Age DESC LIMIT 1
# medium gold: SELECT song_name ,  song_release_year FROM singer ORDER BY age LIMIT 1
#
# medium pred: SELECT max(capacity) , avg(average) FROM stadium
# medium gold: select max(capacity), average from stadium
#
# eval_err_num:1
# medium pred: SELECT T1.Name , COUNT(*) FROM stadium AS T1 JOIN concerts AS T2 ON T1.Stadium_ID = T2.Stadium_ID GROUP BY T1.Stadium_ID
# medium gold: SELECT T2.name ,  count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id GROUP BY T1.stadium_id
#
# eval_err_num:2
# medium pred: SELECT T1.Name , COUNT(*) FROM stadium AS T1 JOIN concerts AS T2 ON T1.Stadium_ID = T2.Stadium_ID GROUP BY T1.Stadium_ID
# medium gold: SELECT T2.name ,  count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id GROUP BY T1.stadium_id
#
# eval_err_num:3
# extra pred: SELECT T1.Name , T1.Capacity FROM stadium AS T1 JOIN concerts AS T2 ON T1.Stadium_ID = T2.Stadium_ID WHERE T2.Year = 2014 ORDER BY T2.Capacity DESC LIMIT 1
# extra gold: SELECT T2.name ,  T2.capacity FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  >=  2014 GROUP BY T2.stadium_id ORDER BY count(*) DESC LIMIT 1
#
# eval_err_num:4
# extra pred: SELECT T1.Name , T1.Capacity FROM stadium AS T1 JOIN concerts AS T2 ON T1.Stadium_ID = T2.Stadium_ID WHERE T2.Highest > 2013 GROUP BY T2.Stadium_ID ORDER BY COUNT(*) DESC LIMIT 1
# extra gold: select t2.name ,  t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id  =  t2.stadium_id where t1.year  >  2013 group by t2.stadium_id order by count(*) desc limit 1
#
# eval_err_num:5
# hard pred: SELECT Name FROM stadium WHERE Location NOT IN (SELECT Stadium_ID FROM stadium WHERE Location NOT IN (SELECT Stadium_ID FROM concert)
# hard gold: SELECT name FROM stadium WHERE stadium_id NOT IN (SELECT stadium_id FROM concert)
#
# eval_err_num:6
# hard pred: SELECT Name FROM stadium WHERE Stadium_ID NOT IN (SELECT Stadium_ID FROM concerts)
# hard gold: SELECT name FROM stadium WHERE stadium_id NOT IN (SELECT stadium_id FROM concert)
#
# eval_err_num:7
# hard pred: SELECT Country FROM singer WHERE Age > 40 INTERSECT SELECT Country FROM singer WHERE Age  30
# hard gold: SELECT country FROM singer WHERE age  >  40 INTERSECT SELECT country FROM singer WHERE age  <  30
#
# hard pred: SELECT T1.name FROM stadium AS T1 JOIN concert AS T2 ON T1.stadium_id = T2.stadium_id WHERE T2.year = 2014
# hard gold: SELECT name FROM stadium EXCEPT SELECT T2.name FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  =  2014
#
# eval_err_num:8
# hard pred: SELECT Name FROM stadium WHERE Stadium_ID NOT IN (SELECT Stadium_ID FROM concert WHERE 2014)
# hard gold: SELECT name FROM stadium EXCEPT SELECT T2.name FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  =  2014
#
# eval_err_num:9
# medium pred: SELECT T2.contest_name , T2.theme , count(*) FROM concert AS T1 JOIN singer AS T2 ON T1.concert_id = T2.concert_id GROUP BY T1.concert_name
# medium gold: SELECT T2.concert_name ,  T2.theme ,  count(*) FROM singer_in_concert AS T1 JOIN concert AS T2 ON T1.concert_id  =  T2.concert_id GROUP BY T2.concert_id
#
# medium pred: SELECT T1.concert_name , T1.theme , count(*) FROM concert AS T1 JOIN concert AS T2 ON T1.concert_id = T2.concert_id GROUP BY T1.concert_name
# medium gold: select t2.concert_name ,  t2.theme ,  count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id  =  t2.concert_id group by t2.concert_id
#
# medium pred: SELECT T1.Name , COUNT(*) FROM singer AS T1 JOIN singer AS T2 ON T1.Singer_ID = T2.Singer_ID GROUP BY T1.Singer_ID
# medium gold: SELECT T2.name ,  count(*) FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id GROUP BY T2.singer_id
#
# eval_err_num:10
# medium pred: SELECT T1.Name , COUNT(*) FROM singer AS T1 JOIN concert AS T2 ON T1.Singer_ID = T2.Singer_ID GROUP BY T1.Singer_ID
# medium gold: SELECT T2.name ,  count(*) FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id GROUP BY T2.singer_id
#
# eval_err_num:11
# hard pred: SELECT T1.Name FROM concert AS T1 JOIN singer AS T2 ON T1.Singer_ID = T2.Singer_ID WHERE T2.Year = 2014
# hard gold: SELECT T2.name FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id JOIN concert AS T3 ON T1.concert_id  =  T3.concert_id WHERE T3.year  =  2014
#
# eval_err_num:12
# hard pred: SELECT T1.Name FROM singer AS T1 JOIN concert AS T2 ON T1.Singer_ID = T2.Singer_ID WHERE T2.Year = 2014
# hard gold: SELECT T2.name FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id JOIN concert AS T3 ON T1.concert_id  =  T3.concert_id WHERE T3.year  =  2014
#
# medium pred: SELECT T1.Name , T1.Country FROM singer AS T1 JOIN singer AS T2 ON T1.Singer_ID = T2.Singer_ID WHERE T2.Song_Name LIKE '%Hey%'
# medium gold: SELECT name ,  country FROM singer WHERE song_name LIKE '%Hey%'
#
# medium pred: SELECT T1.Name , T1.Country FROM singer AS T1 JOIN singer AS T2 ON T1.Singer_ID = T2.Singer_ID WHERE T2.Song_Name LIKE '%Hey%'
# medium gold: SELECT name ,  country FROM singer WHERE song_name LIKE '%Hey%'
#
# hard pred: SELECT count(*) FROM stadium ORDER BY capacity DESC LIMIT 1
# hard gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#
# hard pred: SELECT count(*) FROM stadium WHERE capacity = (SELECT max(capacity) FROM stadium)
# hard gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#
# eval_err_num:13
# medium pred: SELECT min(weight) FROM dog ORDER BY age DESC LIMIT 1
# medium gold: SELECT weight FROM pets ORDER BY pet_age LIMIT 1
#
# eval_err_num:14
# medium pred: SELECT min(weight) FROM dog ORDER BY age DESC LIMIT 1
# medium gold: SELECT weight FROM pets ORDER BY pet_age LIMIT 1
#
# eval_err_num:15
# medium pred: SELECT max(weight) , pet_type FROM Pets GROUP BY pet_type
# medium gold: SELECT max(weight) ,  petType FROM pets GROUP BY petType
#
# eval_err_num:16
# medium pred: SELECT max(weight) , pet_type FROM Pets GROUP BY pet_type
# medium gold: SELECT max(weight) ,  petType FROM pets GROUP BY petType
#
# eval_err_num:17
# medium pred: SELECT count(*) FROM pets WHERE student > 20
# medium gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20
#
# eval_err_num:18
# medium pred: SELECT count(*) FROM pets WHERE age > 20
# medium gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20
#
# eval_err_num:19
# hard pred: SELECT count(*) FROM pet AS t1 JOIN dog AS t2 ON t1.dog = t2.dog WHERE t2.sex = 'F'
# hard gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T2.petid  =  T3.petid WHERE T1.sex  =  'F' AND T3.pettype  =  'dog'
#
# eval_err_num:20
# hard pred: SELECT count(*) FROM pet AS T1 JOIN dog AS T2 ON T1.dog = T2.dog WHERE T2.student = 'female'
# hard gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T2.petid  =  T3.petid WHERE T1.sex  =  'F' AND T3.pettype  =  'dog'
#
# eval_err_num:21
# extra pred: SELECT firstname FROM student WHERE pet = 'cat' OR pet = 'dog'
# extra gold: SELECT DISTINCT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' OR T3.pettype  =  'dog'
#
# eval_err_num:22
# extra pred: SELECT T1.first_name FROM student AS T1 JOIN pet AS T2 ON T1.student = T2.first_name WHERE T2.pet = 'Cat' OR T2.pet = 'Dog'
# extra gold: SELECT DISTINCT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' OR T3.pettype  =  'dog'
#
# eval_err_num:23
# extra pred: SELECT T1.first_name FROM student AS T1 JOIN student AS T2 ON T1.student = T2.student WHERE T2.pets = 'cat' INTERSECT SELECT T1.first_name FROM student AS T1 JOIN student AS T2 ON T1.student = T2.student WHERE T2.pets = 'dog'
# extra gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid  =  t2.stuid join pets as t3 on t3.petid  =  t2.petid where t3.pettype  =  'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid  =  t2.stuid join pets as t3 on t3.petid  =  t2.petid where t3.pettype  =  'dog'
#
# eval_err_num:24
# extra pred: SELECT T1.first_name FROM student AS T1 JOIN pets AS T2 ON T1.first_name = T2.first_name WHERE T2.pets = "cats" INTERSECT SELECT T1.first_name FROM student AS T1 JOIN pets AS T2 ON T1.first_name = T2.first_name WHERE T2.pets = "dogs"
# extra gold: SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' INTERSECT SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog'
#
# eval_err_num:25
# extra pred: SELECT major , age FROM student WHERE student EXCEPT SELECT major , age FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT
# extra gold: SELECT major ,  age FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')
#
# eval_err_num:26
# extra pred: SELECT major , age FROM student WHERE student EXCEPT SELECT major , age FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT major FROM student WHERE student EXCEPT SELECT major FROM student
# extra gold: SELECT major ,  age FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')
#
# eval_err_num:27
# hard pred: SELECT T1.id FROM student AS T1 JOIN student AS T2 ON T1.id = T2.student WHERE T2.pet = "cat" EXCEPT SELECT T1.id FROM student AS T1 JOIN student AS T2 ON T1.id = T2.student WHERE T2.pet = "cat"
# hard gold: SELECT stuid FROM student EXCEPT SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat'
#
# eval_err_num:28
# hard pred: SELECT T1.id FROM student AS T1 JOIN student AS T2 ON T1.id = T2.student WHERE T2.pets = 'Cats' EXCEPT SELECT T1.id FROM student AS T1 JOIN student AS T2 ON T1.student = T2.student WHERE T2.pets = 'Cats'
# hard gold: SELECT stuid FROM student EXCEPT SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat'
#
# eval_err_num:29
# extra pred: SELECT T1.first_name , T1.age FROM student AS T1 JOIN student AS T2 ON T1.student = T2.student WHERE T2.pet = 'dog' EXCEPT SELECT T1.first_name , T1.age FROM student AS T1 JOIN student AS T2 ON T1.student = T2.student WHERE T2.pet = 'cat'
# extra gold: SELECT T1.fname ,  T1.age FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog' AND T1.stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')
#
# eval_err_num:30
# extra pred: SELECT T1.firstname FROM student AS T1 JOIN student AS T2 ON T1.stuid = T2.stuid WHERE T2.name = 'dog' INTERSECT SELECT T1.firstname FROM student AS T1 JOIN student AS T2 ON T1.stuid = T2.stuid WHERE T2.name = 'cat'
# extra gold: SELECT T1.fname ,  T1.age FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog' AND T1.stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')
#
# eval_err_num:31
# medium pred: SELECT TYPE , weight FROM pet ORDER BY age DESC LIMIT 1
# medium gold: SELECT pettype ,  weight FROM pets ORDER BY pet_age LIMIT 1
#
# eval_err_num:32
# medium pred: SELECT TYPE , COUNT(*) FROM pet ORDER BY COUNT(*) DESC LIMIT 1
# medium gold: SELECT pettype ,  weight FROM pets ORDER BY pet_age LIMIT 1
#
# eval_err_num:33
# medium pred: SELECT id , weight FROM pets WHERE age > 1
# medium gold: SELECT petid ,  weight FROM pets WHERE pet_age  >  1
#
# eval_err_num:34
# medium pred: SELECT id , weight FROM pet WHERE age > 1
# medium gold: SELECT petid ,  weight FROM pets WHERE pet_age  >  1
#
# eval_err_num:35
# medium pred: SELECT avg(age) , max(age) , type FROM pet GROUP BY type
# medium gold: SELECT avg(pet_age) ,  max(pet_age) ,  pettype FROM pets GROUP BY pettype
#
# eval_err_num:36
# medium pred: SELECT avg(age) , max(age) , pet FROM Pet GROUP BY pet
# medium gold: SELECT avg(pet_age) ,  max(pet_age) ,  pettype FROM pets GROUP BY pettype
#
# eval_err_num:37
# medium pred: SELECT T1.first_name , T1.age FROM student AS T1 JOIN pet AS T2 ON T1.student = T2.student WHERE T2.age = 'pet'
# medium gold: SELECT DISTINCT T1.fname ,  T1.age FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid
#
# eval_err_num:38
# medium pred: SELECT DISTINCT T1.first_name , T1.age FROM student AS T1 JOIN pets AS T2 ON T1.student = T2.student WHERE T2.age = 'pets'
# medium gold: SELECT DISTINCT T1.fname ,  T1.age FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid
#
# eval_err_num:39
# medium pred: SELECT t1.id FROM pet AS t1 JOIN pet AS t2 ON t1.id = t2.pet_id WHERE t2.lastname = 'Smith'
# medium gold: SELECT T2.petid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.Lname  =  'Smith'
#
# eval_err_num:40
# medium pred: SELECT t1.id FROM pet AS t1 JOIN student AS t2 ON t1.id = t2.pet_id WHERE t2.lastname = 'Smith'
# medium gold: SELECT T2.petid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.Lname  =  'Smith'
#
# eval_err_num:41
# medium pred: SELECT count(*) , student_id FROM student GROUP BY student_id
# medium gold: SELECT count(*) ,  T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid
#
# eval_err_num:42
# medium pred: SELECT count(*) , T1.id FROM student AS T1 JOIN pets AS T2 ON T1.id = T2.pets GROUP BY T1.id
# medium gold: select count(*) ,  t1.stuid from student as t1 join has_pet as t2 on t1.stuid  =  t2.stuid group by t1.stuid
#
# eval_err_num:43
# medium pred: SELECT T1.first_name , T1.gender FROM student AS T1 JOIN pet AS T2 ON T1.student = T2.stuid GROUP BY T1.first_name HAVING count(*) > 1
# medium gold: SELECT T1.fname ,  T1.sex FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid HAVING count(*)  >  1
#
# eval_err_num:44
# medium pred: SELECT T1.first_name , T1.gender FROM student AS T1 JOIN pet AS T2 ON T1.stuid = T2.stuid GROUP BY T1.stuid HAVING count(*) > 1
# medium gold: SELECT T1.fname ,  T1.sex FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid HAVING count(*)  >  1
#
# eval_err_num:45
# hard pred: SELECT T1.lastname FROM student AS T1 JOIN cat AS T2 ON T1.stuid = T2.cat WHERE T2.age = 3
# hard gold: SELECT T1.lname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pet_age  =  3 AND T3.pettype  =  'cat'
#
# eval_err_num:46
# hard pred: SELECT T1.lastname FROM student AS T1 JOIN cat AS T2 ON T1.stuid = T2.cat WHERE T2.age = 3
# hard gold: SELECT T1.lname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pet_age  =  3 AND T3.pettype  =  'cat'
#
# eval_err_num:47
# extra pred: SELECT avg(age) FROM student WHERE student EXCEPT SELECT avg(age) FROM student WHERE student EXCEPT SELECT avg(age) FROM pet
# extra gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#
# eval_err_num:48
# extra pred: SELECT avg(age) FROM student WHERE student EXCEPT SELECT avg(age) FROM student WHERE student EXCEPT SELECT avg(age) FROM pet
# extra gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#
# eval_err_num:49
# medium pred: SELECT T1.ContId , T1.Continent , COUNT(*) , COUNT(*) FROM continents AS T1 JOIN countries AS T2 ON T1.CountryId = T2.CountryId GROUP BY T1.ContId
# medium gold: SELECT T1.ContId ,  T1.Continent ,  count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId  =  T2.Continent GROUP BY T1.ContId;
#
# eval_err_num:50
# medium pred: SELECT T1.Continent , T1.Name , COUNT(*) FROM continents AS T1 JOIN countries AS T2 ON T1.Continent = T2.CountryId GROUP BY T1.Continent
# medium gold: SELECT T1.ContId ,  T1.Continent ,  count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId  =  T2.Continent GROUP BY T1.ContId;
#
# medium pred: SELECT T1.FullName , T1.Id , COUNT(*) FROM car_makers AS T1 JOIN car_makers AS T2 ON T1.Id = T2.Maker GROUP BY T1.FullName
# medium gold: SELECT T1.FullName ,  T1.Id ,  count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id;
#
# medium pred: SELECT T1.FullName , T1.Id , COUNT(*) FROM car_makers AS T1 JOIN car_makers AS T2 ON T1.Maker = T2.Id GROUP BY T1.Maker
# medium gold: SELECT T1.FullName ,  T1.Id ,  count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id;
#
# eval_err_num:51
# hard pred: SELECT Model FROM car_names ORDER BY Horsepower ASC LIMIT 1
# hard gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id ORDER BY T2.horsepower ASC LIMIT 1;
#
# eval_err_num:52
# hard pred: SELECT Model FROM car_names ORDER BY Horsepower ASC LIMIT 1
# hard gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id ORDER BY T2.horsepower ASC LIMIT 1;
#
# eval_err_num:53
# extra pred: SELECT model FROM model_list WHERE weight  (SELECT avg(weight) FROM model_list)
# extra gold: SELECT T1.model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Weight  <  (SELECT avg(Weight) FROM CARS_DATA)
#
# eval_err_num:54
# extra pred: SELECT model FROM model_list WHERE model  (SELECT avg(size) FROM model_list)
# extra gold: SELECT T1.model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Weight  <  (SELECT avg(Weight) FROM CARS_DATA)
#
# eval_err_num:55
# extra pred: SELECT T1.Maker FROM car_makers AS T1 JOIN car_makers AS T2 ON T1.Id = T2.Maker WHERE T2.Year = 1970
# extra gold: SELECT DISTINCT T1.Maker FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker JOIN CAR_NAMES AS T3 ON T2.model  =  T3.model JOIN CARS_DATA AS T4 ON T3.MakeId  =  T4.id WHERE T4.year  =  '1970';
#
# extra pred: SELECT DISTINCT T1.Maker FROM car_makers AS T1 JOIN car_makers AS T2 ON T1.Id = T2.Maker WHERE T2.Maker = 1970
# extra gold: SELECT DISTINCT T1.Maker FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker JOIN CAR_NAMES AS T3 ON T2.model  =  T3.model JOIN CARS_DATA AS T4 ON T3.MakeId  =  T4.id WHERE T4.year  =  '1970';
#
# eval_err_num:56
# extra pred: SELECT T1.Make , T1.ProductionTime FROM car_makers AS T1 JOIN car_names AS T2 ON T1.MakeId = T2.MakeId ORDER BY T2.Make ASC LIMIT 1
# extra gold: SELECT T2.Make ,  T1.Year FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T1.Year  =  (SELECT min(YEAR) FROM CARS_DATA);
#
# extra pred: SELECT Maker , COUNT(*) FROM car_makers ORDER BY COUNT(*) DESC LIMIT 1
# extra gold: SELECT T2.Make ,  T1.Year FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T1.Year  =  (SELECT min(YEAR) FROM CARS_DATA);
#
# eval_err_num:57
# hard pred: SELECT DISTINCT T1.Make , T1.FullName FROM car_makers AS T1 JOIN car_makers AS T2 ON T1.Id = T2.Make WHERE T2.Make > 1980
# hard gold: SELECT DISTINCT T1.model FROM MODEL_LIST AS T1 JOIN CAR_NAMES AS T2 ON T1.model  =  T2.model JOIN CARS_DATA AS T3 ON T2.MakeId  =  T3.id WHERE T3.year  >  1980;
#
# hard pred: SELECT DISTINCT Model FROM model_list WHERE Maker > 1980
# hard gold: SELECT DISTINCT T1.model FROM MODEL_LIST AS T1 JOIN CAR_NAMES AS T2 ON T1.model  =  T2.model JOIN CARS_DATA AS T3 ON T2.MakeId  =  T3.id WHERE T3.year  >  1980;
#
# eval_err_num:58
# hard pred: SELECT T2.Maker , count(*) FROM car_makers AS T1 JOIN continents AS T2 ON T1.Continent = T2.Continent GROUP BY T1.Continent
# hard gold: SELECT T1.Continent ,  count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId  =  T2.continent JOIN car_makers AS T3 ON T2.CountryId  =  T3.Country GROUP BY T1.Continent;
#
# hard pred: SELECT T1.Continent , count(*) FROM continents AS T1 JOIN car_makers AS T2 ON T1.Continent = T2.Id GROUP BY T1.Continent
# hard gold: SELECT T1.Continent ,  count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId  =  T2.continent JOIN car_makers AS T3 ON T2.CountryId  =  T3.Country GROUP BY T1.Continent;
#
# eval_err_num:59
# extra pred: SELECT T1.countryname FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.countryid GROUP BY T1.countryname ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T2.CountryName FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId GROUP BY T1.Country ORDER BY Count(*) DESC LIMIT 1;
#
# eval_err_num:60
# extra pred: SELECT T1.countryname FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.countryid GROUP BY T1.countryname ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T2.CountryName FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId GROUP BY T1.Country ORDER BY Count(*) DESC LIMIT 1;
#
# medium pred: SELECT count(*) , T1.FullName FROM car_makers AS T1 JOIN car_makers AS T2 ON T1.Id = T2.Maker GROUP BY T1.Maker
# medium gold: select count(*) ,  t2.fullname from model_list as t1 join car_makers as t2 on t1.maker  =  t2.id group by t2.id;
#
# medium pred: SELECT Maker , FullName FROM car_makers GROUP BY Maker
# medium gold: SELECT Count(*) ,  T2.FullName ,  T2.id FROM MODEL_LIST AS T1 JOIN CAR_MAKERS AS T2 ON T1.Maker  =  T2.Id GROUP BY T2.id;
#
# eval_err_num:61
# medium pred: SELECT accelerate FROM car_names WHERE make = 'amc hornet sportabout (sw)'
# medium gold: SELECT T1.Accelerate FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Make  =  'amc hornet sportabout (sw)';
#
# eval_err_num:62
# medium pred: SELECT T2.Aggravate FROM cars_data AS T1 JOIN car_names AS T2 ON T1.MakeId = T2.MakeId JOIN car_names AS T3 ON T1.MakeId = T3.MakeId WHERE T3.Make = "amc hornet sportabout (sw)"
# medium gold: SELECT T1.Accelerate FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Make  =  'amc hornet sportabout (sw)';
#
# medium pred: SELECT count(*) FROM car_makers WHERE country = 'France'
# medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId WHERE T2.CountryName  =  'france';
#
# medium pred: SELECT count(*) FROM car_makers WHERE country = 'France'
# medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId WHERE T2.CountryName  =  'france';
#
# hard pred: SELECT count(*) FROM car_makers WHERE country = 'United States'
# hard gold: SELECT count(*) FROM MODEL_LIST AS T1 JOIN CAR_MAKERS AS T2 ON T1.Maker  =  T2.Id JOIN COUNTRIES AS T3 ON T2.Country  =  T3.CountryId WHERE T3.CountryName  =  'usa';
#
# hard pred: SELECT count(*) FROM car_makers WHERE country = "United States"
# hard gold: SELECT count(*) FROM MODEL_LIST AS T1 JOIN CAR_MAKERS AS T2 ON T1.Maker  =  T2.Id JOIN COUNTRIES AS T3 ON T2.Country  =  T3.CountryId WHERE T3.CountryName  =  'usa';
#
# eval_err_num:63
# medium pred: SELECT MIN(T1.Weight) FROM cars_names AS T1 JOIN car_names AS T2 ON T1.MakeId = T2.MakeId WHERE T2.Year = 1974 AND T1.Cylinders = 8
# medium gold: select min(weight) from cars_data where cylinders  =  8 and year  =  1974
#
# eval_err_num:64
# medium pred: SELECT min(T1.Weight) FROM cars_data AS T1 JOIN cars AS T2 ON T1.MakeId = T2.MakeId WHERE T2.Year = 1974 AND T1.Cylinders = 8
# medium gold: select min(weight) from cars_data where cylinders  =  8 and year  =  1974
#
# eval_err_num:65
# medium pred: SELECT Maker , Model FROM car_makers
# medium gold: SELECT Maker ,  Model FROM MODEL_LIST;
#
# eval_err_num:66
# medium pred: SELECT T1.countryname , T1.id FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.countryid GROUP BY T1.countryname HAVING count(*) >= 1
# medium gold: SELECT T1.CountryName ,  T1.CountryId FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY T1.CountryId HAVING count(*)  >=  1;
#
# eval_err_num:67
# medium pred: SELECT T1.countryname , T1.id FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.countryid GROUP BY T1.countryname HAVING count(*) >= 1
# medium gold: SELECT T1.CountryName ,  T1.CountryId FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY T1.CountryId HAVING count(*)  >=  1;
#
# eval_err_num:68
# medium pred: SELECT avg(weight) , YEAR FROM cars GROUP BY YEAR
# medium gold: SELECT avg(Weight) ,  YEAR FROM CARS_DATA GROUP BY YEAR;
#
# eval_err_num:69
# extra pred: SELECT T1.countryname FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.countryid GROUP BY T1.countryname HAVING count(*) >= 3
# extra gold: SELECT T1.CountryName FROM COUNTRIES AS T1 JOIN CONTINENTS AS T2 ON T1.Continent  =  T2.ContId JOIN CAR_MAKERS AS T3 ON T1.CountryId  =  T3.Country WHERE T2.Continent  =  'europe' GROUP BY T1.CountryName HAVING count(*)  >=  3;
#
# eval_err_num:70
# extra pred: SELECT T1.countryname FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.countryid WHERE T2.Maker = INTERSECT SELECT T1.countryname FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.countryid WHERE T2.Maker = INTERSECT SELECT T1.countryname FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.countryid WHERE T
# extra gold: SELECT T1.CountryName FROM COUNTRIES AS T1 JOIN CONTINENTS AS T2 ON T1.Continent  =  T2.ContId JOIN CAR_MAKERS AS T3 ON T1.CountryId  =  T3.Country WHERE T2.Continent  =  'europe' GROUP BY T1.CountryName HAVING count(*)  >=  3;
#
# eval_err_num:71
# extra pred: SELECT max(horsepower) , make FROM car_names WHERE Model = 3
# extra gold: SELECT T2.horsepower ,  T1.Make FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.cylinders  =  3 ORDER BY T2.horsepower DESC LIMIT 1;
#
# eval_err_num:72
# extra pred: SELECT max(horsepower) , make FROM car_names WHERE model = 3
# extra gold: SELECT T2.horsepower ,  T1.Make FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.cylinders  =  3 ORDER BY T2.horsepower DESC LIMIT 1;
#
# eval_err_num:73
# hard pred: SELECT t1.model FROM model_list AS t1 JOIN model AS t2 ON t1.model = t2.modelid ORDER BY t2.miles per gallon DESC LIMIT 1
# hard gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id ORDER BY T2.mpg DESC LIMIT 1;
#
# eval_err_num:74
# hard pred: SELECT Model FROM car_names ORDER BY MPG DESC LIMIT 1
# hard gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid  =  t2.id order by t2.mpg desc limit 1;
#
# eval_err_num:75
# easy pred: SELECT avg(Horsepower) FROM cars_data WHERE YEAR  1980
# easy gold: SELECT avg(horsepower) FROM CARS_DATA WHERE YEAR  <  1980;
#
# easy pred: SELECT avg(Horsepower) FROM cars_data WHERE YEAR > 1980
# easy gold: select avg(horsepower) from cars_data where year  <  1980;
#
# eval_err_num:76
# medium pred: SELECT avg(edispl) FROM model_list WHERE model = 'Volvo'
# medium gold: SELECT avg(T2.edispl) FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T1.Model  =  'volvo';
#
# eval_err_num:77
# medium pred: SELECT avg(Edispl) FROM cars_data WHERE Model = "Volvo"
# medium gold: SELECT avg(T2.edispl) FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T1.Model  =  'volvo';
#
# medium pred: SELECT max(accelerate) , COUNT(*) FROM cars_data GROUP BY Cylinders
# medium gold: SELECT max(Accelerate) ,  Cylinders FROM CARS_DATA GROUP BY Cylinders;
#
# medium pred: SELECT max(accelerate) FROM cars_data GROUP BY Cylinders
# medium gold: SELECT max(Accelerate) ,  Cylinders FROM CARS_DATA GROUP BY Cylinders;
#
# eval_err_num:78
# hard pred: SELECT T1.Model FROM model_list AS T1 JOIN car_names AS T2 ON T1.MakeId = T2.MakeId GROUP BY T1.MakeId ORDER BY count(*) DESC LIMIT 1
# hard gold: SELECT Model FROM CAR_NAMES GROUP BY Model ORDER BY count(*) DESC LIMIT 1;
#
# hard pred: SELECT DISTINCT Model FROM model_list GROUP BY Model ORDER BY COUNT(*) DESC LIMIT 1
# hard gold: SELECT Model FROM CAR_NAMES GROUP BY Model ORDER BY count(*) DESC LIMIT 1;
#
# eval_err_num:79
# easy pred: SELECT count(*) FROM cars_names WHERE YEAR = 1980
# easy gold: SELECT count(*) FROM CARS_DATA WHERE YEAR  =  1980;
#
# easy pred: SELECT count(*) FROM car_makers WHERE Maker = 1980
# easy gold: SELECT count(*) FROM CARS_DATA WHERE YEAR  =  1980;
#
# medium pred: SELECT count(*) FROM car_makers WHERE fullname = "American Motor Company"
# medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker WHERE T1.FullName  =  'American Motor Company';
#
# medium pred: SELECT count(*) FROM car_makers WHERE Maker = "American Motor Company"
# medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker WHERE T1.FullName  =  'American Motor Company';
#
# medium pred: SELECT T1.FullName , T1.Id FROM car_makers AS T1 JOIN car_makers AS T2 ON T1.Maker = T2.Id GROUP BY T1.Maker HAVING count(*) > 3
# medium gold: SELECT T1.FullName ,  T1.Id FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id HAVING count(*)  >  3;
#
# medium pred: SELECT T2.Maker , T2.Id FROM car_makers AS T1 JOIN car_makers AS T2 ON T1.Maker = T2.Id GROUP BY T1.Maker HAVING count(*) > 3
# medium gold: SELECT T1.FullName ,  T1.Id FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id HAVING count(*)  >  3;
#
# eval_err_num:80
# extra pred: SELECT DISTINCT Model FROM model_list WHERE Maker = "General Motors" OR Weight > 3500
# extra gold: SELECT DISTINCT T2.Model FROM CAR_NAMES AS T1 JOIN MODEL_LIST AS T2 ON T1.Model  =  T2.Model JOIN CAR_MAKERS AS T3 ON T2.Maker  =  T3.Id JOIN CARS_DATA AS T4 ON T1.MakeId  =  T4.Id WHERE T3.FullName  =  'General Motors' OR T4.weight  >  3500;
#
# eval_err_num:81
# extra pred: SELECT DISTINCT Model FROM model_list WHERE Maker = "General Motors" OR Weight > 3500
# extra gold: SELECT DISTINCT T2.Model FROM CAR_NAMES AS T1 JOIN MODEL_LIST AS T2 ON T1.Model  =  T2.Model JOIN CAR_MAKERS AS T3 ON T2.Maker  =  T3.Id JOIN CARS_DATA AS T4 ON T1.MakeId  =  T4.Id WHERE T3.FullName  =  'General Motors' OR T4.weight  >  3500;
#
# eval_err_num:82
# easy pred: SELECT YEAR FROM cars_names WHERE Weight  3000 INTERSECT SELECT YEAR FROM cars_names WHERE Weight > 4000
# easy gold: select distinct year from cars_data where weight between 3000 and 4000;
#
# eval_err_num:83
# easy pred: SELECT DISTINCT YEAR FROM cars_manufacturer WHERE Weight  4000 INTERSECT SELECT YEAR FROM cars_manufacturer WHERE Weight > 3000
# easy gold: select distinct year from cars_data where weight between 3000 and 4000;
#
# eval_err_num:84
# extra pred: SELECT T2.Cylinders FROM car_names AS T1 JOIN model_list AS T2 ON T1.MakeId = T2.MakeId JOIN car_names AS T3 ON T1.Model = T3.MakeId WHERE T3.Model = "Volvo" GROUP BY T1.MakeId ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T1.cylinders FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Model  =  'volvo' ORDER BY T1.accelerate ASC LIMIT 1;
#
# eval_err_num:85
# extra pred: SELECT T2.Cylinders FROM model_list AS T1 JOIN car_names AS T2 ON T1.MakeId = T2.MakeId GROUP BY T1.MakeId ORDER BY COUNT(*) DESC LIMIT 1
# extra gold: SELECT T1.cylinders FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Model  =  'volvo' ORDER BY T1.accelerate ASC LIMIT 1;
#
# hard pred: SELECT count(*) FROM cars_data WHERE Accelerate > (SELECT max(accelerate) FROM cars_data)
# hard gold: SELECT COUNT(*) FROM CARS_DATA WHERE Accelerate  >  ( SELECT Accelerate FROM CARS_DATA ORDER BY Horsepower DESC LIMIT 1 );
#
# hard pred: SELECT count(*) FROM cars_data WHERE Accelerate > (SELECT max(accelerate) FROM cars_data)
# hard gold: SELECT COUNT(*) FROM CARS_DATA WHERE Accelerate  >  ( SELECT Accelerate FROM CARS_DATA ORDER BY Horsepower DESC LIMIT 1 );
#
# eval_err_num:86
# medium pred: SELECT count(*) FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.countryid GROUP BY T1.countryid HAVING count(*) > 2
# medium gold: select count(*) from countries as t1 join car_makers as t2 on t1.countryid  =  t2.country group by t1.countryid having count(*)  >  2
#
# eval_err_num:87
# medium pred: SELECT count(*) FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.id GROUP BY T1.countryid HAVING count(*) > 2
# medium gold: select count(*) from countries as t1 join car_makers as t2 on t1.countryid  =  t2.country group by t1.countryid having count(*)  >  2
#
# eval_err_num:88
# extra pred: SELECT t1.Model FROM cars AS t1 JOIN model_list AS t2 ON t1.MakeId = t2.MakeId JOIN car_names AS t3 ON t2.Model = t3.MakeId WHERE t3.cylinders = 4 AND t3.horsepower = (SELECT max(horsepower) FROM cars_data)
# extra gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Cylinders  =  4 ORDER BY T2.horsepower DESC LIMIT 1;
#
# eval_err_num:89
# extra pred: SELECT t1.Model FROM cars AS t1 JOIN model_list AS t2 ON t1.MakeId = t2.MakeId JOIN car_names AS t3 ON t2.Model = t3.MakeId GROUP BY t1.Model ORDER BY count(*) DESC LIMIT 4
# extra gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Cylinders  =  4 ORDER BY T2.horsepower DESC LIMIT 1;
#
# eval_err_num:90
# extra pred: SELECT T1.MakeId , T1.MakeName FROM car_names AS T1 JOIN car_names AS T2 ON T1.MakeId = T2.MakeId WHERE T2.horse > 3
# extra gold: SELECT T2.MakeId ,  T2.Make FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T1.Horsepower  >  (SELECT min(Horsepower) FROM CARS_DATA) AND T1.Cylinders  <=  3;
#
# eval_err_num:91
# extra pred: SELECT T1.Make , T1.Name FROM car_names AS T1 JOIN car_names AS T2 ON T1.Make = T2.Make WHERE T2.Make  4
# extra gold: select t2.makeid ,  t2.make from cars_data as t1 join car_names as t2 on t1.id  =  t2.makeid where t1.horsepower  >  (select min(horsepower) from cars_data) and t1.cylinders  <  4;
#
# eval_err_num:92
# medium pred: SELECT max(MPG) FROM cars_data WHERE Cylinders = 8 OR YEAR  1980
# medium gold: select max(mpg) from cars_data where cylinders  =  8 or year  <  1980
#
# eval_err_num:93
# medium pred: SELECT max(mpg) FROM cars_data WHERE Cylinders = 8 OR YEAR  1980
# medium gold: select max(mpg) from cars_data where cylinders  =  8 or year  <  1980
#
# extra pred: SELECT Model FROM model_list WHERE Maker = 'Ford Motor Company' EXCEPT SELECT Model FROM model_list WHERE Maker = 'Ford Motor Company'
# extra gold: SELECT DISTINCT T1.model FROM MODEL_LIST AS T1 JOIN CAR_NAMES AS T2 ON T1.Model  =  T2.Model JOIN CARS_DATA AS T3 ON T2.MakeId  =  T3.Id JOIN CAR_MAKERS AS T4 ON T1.Maker  =  T4.Id WHERE T3.weight  <  3500 AND T4.FullName != 'Ford Motor Company';
#
# extra pred: SELECT DISTINCT Model FROM model_list WHERE Maker = 'Ford Motor Company' EXCEPT SELECT DISTINCT Model FROM model_list WHERE Maker = 'Ford Motor Company'
# extra gold: SELECT DISTINCT T1.model FROM MODEL_LIST AS T1 JOIN CAR_NAMES AS T2 ON T1.Model  =  T2.Model JOIN CARS_DATA AS T3 ON T2.MakeId  =  T3.Id JOIN CAR_MAKERS AS T4 ON T1.Maker  =  T4.Id WHERE T3.weight  <  3500 AND T4.FullName != 'Ford Motor Company';
#
# eval_err_num:94
# hard pred: SELECT CountryName FROM country WHERE CountryID NOT IN (SELECT CountryID FROM car_makers)
# hard gold: SELECT CountryName FROM countries EXCEPT SELECT T1.CountryName FROM countries AS T1 JOIN CAR_MAKERS AS T2 ON T1.countryId  =  T2.Country;
#
# eval_err_num:95
# hard pred: SELECT CountryName FROM country EXCEPT SELECT CountryName FROM car_makers
# hard gold: SELECT CountryName FROM countries EXCEPT SELECT T1.CountryName FROM countries AS T1 JOIN CAR_MAKERS AS T2 ON T1.countryId  =  T2.Country;
#
# eval_err_num:96
# extra pred: SELECT T1.id , T1.maker FROM car_makers AS T1 JOIN car_makers AS T2 ON T1.id = T2.car_makers GROUP BY T1.id HAVING count(*) >= 3
# extra gold: select t1.id ,  t1.maker from car_makers as t1 join model_list as t2 on t1.id  =  t2.maker group by t1.id having count(*)  >=  2 intersect select t1.id ,  t1.maker from car_makers as t1 join model_list as t2 on t1.id  =  t2.maker join car_names as t3 on t2.model  =  t3.model group by t1.id having count(*)  >  3;
#
# extra pred: SELECT T1.Id , T1.Maker FROM car_makers AS T1 JOIN car_makers AS T2 ON T1.Maker = T2.Id GROUP BY T1.Maker HAVING COUNT(*) >= 3
# extra gold: SELECT T1.Id ,  T1.Maker FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id HAVING count(*)  >=  2 INTERSECT SELECT T1.Id ,  T1.Maker FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker JOIN CAR_NAMES AS T3 ON T2.model  =  T3.model GROUP BY T1.Id HAVING count(*)  >  3;
#
# eval_err_num:97
# extra pred: SELECT T1.countryid , T1.countryname FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.id WHERE T2.Maker > 3 OR T2.Fiat = 'fiat'
# extra gold: SELECT T1.countryId ,  T1.CountryName FROM Countries AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY T1.countryId HAVING count(*)  >  3 UNION SELECT T1.countryId ,  T1.CountryName FROM Countries AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country JOIN MODEL_LIST AS T3 ON T2.Id  =  T3.Maker WHERE T3.Model  =  'fiat';
#
# eval_err_num:98
# extra pred: SELECT T1.countryid , T1.countryname FROM country AS T1 JOIN car_makers AS T2 ON T1.countryid = T2.countryid WHERE T2.Maker > 3 OR T2.Fuat Model = 'Fiat'
# extra gold: select t1.countryid ,  t1.countryname from countries as t1 join car_makers as t2 on t1.countryid  =  t2.country group by t1.countryid having count(*)  >  3 union select t1.countryid ,  t1.countryname from countries as t1 join car_makers as t2 on t1.countryid  =  t2.country join model_list as t3 on t2.id  =  t3.maker where t3.model  =  'fiat';
#
# easy pred: SELECT T1.country FROM airlines AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid JOIN airlines AS T3 ON T2.uid = T3.uid WHERE T3.Airline = "JetBlue Airways"
# easy gold: SELECT Country FROM AIRLINES WHERE Airline  =  "JetBlue Airways"
#
# easy pred: SELECT T1.country FROM airlines AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid JOIN airlines AS T3 ON T2.uid = T3.uid WHERE T3.Airline = "Jetblue Airways"
# easy gold: SELECT Country FROM AIRLINES WHERE Airline  =  "JetBlue Airways"
#
# easy pred: SELECT T1.Abbreviation FROM airlines AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid WHERE T2.Airline = "Jetblue Airways"
# easy gold: SELECT Abbreviation FROM AIRLINES WHERE Airline  =  "JetBlue Airways"
#
# medium pred: SELECT T1.Airline , T1.Abbreviation FROM airlines AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid WHERE country = 'United States'
# medium gold: SELECT Airline ,  Abbreviation FROM AIRLINES WHERE Country  =  "USA"
#
# medium pred: SELECT T1.AirportCode , T1.AirportName FROM airports AS T1 JOIN airports AS T2 ON T1.AirportCode = T2.AirportCode WHERE T2.City = "Athena"
# medium gold: SELECT AirportCode ,  AirportName FROM AIRPORTS WHERE city  =  "Anthony"
#
# medium pred: SELECT T1.AirportCode , T1.AirportName FROM airports AS T1 JOIN airports AS T2 ON T1.AirportCode = T2.AirportCode WHERE T2.City = "Athena"
# medium gold: SELECT AirportCode ,  AirportName FROM AIRPORTS WHERE city  =  "Anthony"
#
# medium pred: SELECT T1.city , T1.countryAbbrev FROM airports AS T1 JOIN airports AS T2 ON T1.airportcode = T2.airportcode WHERE T2.city = "Alton"
# medium gold: SELECT City ,  Country FROM AIRPORTS WHERE AirportName  =  "Alton"
#
# medium pred: SELECT T1.city , T1.countryAbbrev FROM airports AS T1 JOIN airports AS T2 ON T1.AirportCode = T2.AirportCode WHERE T2.AirportName = "Alton"
# medium gold: SELECT City ,  Country FROM AIRPORTS WHERE AirportName  =  "Alton"
#
# eval_err_num:99
# easy pred: SELECT count(*) FROM flights AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid JOIN airports AS T3 ON T3.AirportCode = T3.AirportCode WHERE T3.AirportName = "APG"
# easy gold: SELECT count(*) FROM FLIGHTS WHERE SourceAirport  =  "APG"
#
# eval_err_num:100
# easy pred: SELECT count(*) FROM flights AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid JOIN airports AS T3 ON T2.airportcode = T3.airportcode WHERE T3.airportname = 'APG'
# easy gold: SELECT count(*) FROM FLIGHTS WHERE SourceAirport  =  "APG"
#
# eval_err_num:101
# easy pred: SELECT count(*) FROM flights AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid WHERE T2.destination = 'ATO'
# easy gold: SELECT count(*) FROM FLIGHTS WHERE DestAirport  =  "ATO"
#
# eval_err_num:102
# easy pred: SELECT count(*) FROM flights AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid WHERE T2.country = 'ATO'
# easy gold: SELECT count(*) FROM FLIGHTS WHERE DestAirport  =  "ATO"
#
# medium pred: SELECT count(*) FROM airports AS T1 JOIN airports AS T2 ON T1.AirportCode = T2.AirportCode WHERE T1.City = "Aberdeen"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# eval_err_num:103
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN airports AS T2 ON T1.uid = T2.uid JOIN airports AS T3 ON T2.airportcode = T3.airportcode WHERE T3.city = "Aberdeen"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# medium pred: SELECT count(*) FROM airports AS T1 JOIN airports AS T2 ON T1.airportcode = T2.airportcode WHERE T2.city = "Aberdeen"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# eval_err_num:104
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN airports AS T2 ON T1.uid = T2.uid JOIN airports AS T3 ON T2.airportcode = T3.airportcode WHERE T3.city = "Aberdeen"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# eval_err_num:105
# hard pred: SELECT count(*) FROM airports AS T1 JOIN flights AS T2 ON T1.airportcode = T2.airportcode WHERE T1.city = 'Aberdeen' AND T2.destination = 'Ashley'
# hard gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRPORTS AS T3 ON T1.SourceAirport  =  T3.AirportCode WHERE T2.City  =  "Ashley" AND T3.City  =  "Aberdeen"
#
# eval_err_num:106
# hard pred: SELECT count(*) FROM airlines AS t1 JOIN airports AS t2 ON t1.uid = t2.uid JOIN airlines AS t3 ON t2.uid = t3.uid JOIN airports AS t4 ON t3.airportcode = t4.uid JOIN airlines AS t5 ON t4.uid = t5.uid JOIN airports AS t6 ON t5.airportcode = t6
# hard gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRPORTS AS T3 ON T1.SourceAirport  =  T3.AirportCode WHERE T2.City  =  "Ashley" AND T3.City  =  "Aberdeen"
#
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid JOIN airlines AS T3 ON T2.uid = T3.uid WHERE T3.Airline = 'JetBlue Airways'
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRLINES AS T2 ON T1.Airline  =  T2.uid WHERE T2.Airline = "JetBlue Airways"
#
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid JOIN airlines AS T3 ON T2.uid = T3.uid WHERE T3.Airline = "Jetblue Airways"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRLINES AS T2 ON T1.Airline  =  T2.uid WHERE T2.Airline = "JetBlue Airways"
#
# eval_err_num:107
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid WHERE T1.Airline = 'United Airlines' AND T1.Airport = 'ASY'
# medium gold: SELECT count(*) FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.DestAirport  =  "ASY"
#
# eval_err_num:108
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN airports AS T2 ON T1.uid = T2.uid JOIN airports AS T3 ON T2.airportcode = T3.airportcode WHERE T3.AirportName = "ASY"
# medium gold: SELECT count(*) FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.DestAirport  =  "ASY"
#
# eval_err_num:109
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN airlines AS T2 ON T1.uid = T2.uid JOIN airlines AS T3 ON T2.uid = T3.uid WHERE T3.Airport = 'AHD'
# medium gold: SELECT count(*) FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.SourceAirport  =  "AHD"
#
# eval_err_num:110
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN airports AS T2 ON T1.uid = T2.uid JOIN airlines AS T3 ON T2.uid = T3.uid WHERE T3.AirportName = "United Airlines" AND T3.AirportName = "AHD Airport"
# medium gold: SELECT count(*) FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.SourceAirport  =  "AHD"
#
# eval_err_num:111
# hard pred: SELECT count(*) FROM airlines AS t1 JOIN airports AS t2 ON t1.uid = t2.uid JOIN airports AS t3 ON t2.airportcode = t3.airportcode WHERE t3.city = 'Aberdeen'
# hard gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRLINES AS T3 ON T3.uid  =  T1.Airline WHERE T2.City  =  "Aberdeen" AND T3.Airline  =  "United Airlines"
#
# eval_err_num:112
# hard pred: SELECT count(*) FROM airlines AS t1 JOIN airports AS t2 ON t1.uid = t2.uid JOIN airports AS t3 ON t2.airportcode = t3.airportcode WHERE t3.city = "Aberdeen"
# hard gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRLINES AS T3 ON T3.uid  =  T1.Airline WHERE T2.City  =  "Aberdeen" AND T3.Airline  =  "United Airlines"
#
# extra pred: SELECT city FROM airports GROUP BY city ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport GROUP BY T1.City ORDER BY count(*) DESC LIMIT 1
#
# extra pred: SELECT city FROM airports GROUP BY city ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport GROUP BY T1.City ORDER BY count(*) DESC LIMIT 1
#
# extra pred: SELECT city FROM airports GROUP BY city ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.SourceAirport GROUP BY T1.City ORDER BY count(*) DESC LIMIT 1
#
# extra pred: SELECT city FROM airports GROUP BY city ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.SourceAirport GROUP BY T1.City ORDER BY count(*) DESC LIMIT 1
#
# extra pred: SELECT airportcode FROM airports GROUP BY airportcode ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport GROUP BY T1.AirportCode ORDER BY count(*) DESC LIMIT 1
#
# extra pred: SELECT airportcode FROM airports GROUP BY airportcode ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport GROUP BY T1.AirportCode ORDER BY count(*) DESC LIMIT 1
#
# extra pred: SELECT airportcode FROM airports GROUP BY airportcode ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport GROUP BY T1.AirportCode ORDER BY count(*) LIMIT 1
#
# eval_err_num:113
# extra pred: SELECT AirportCode FROM airports ORDER BY AirportDESC LIMIT 1
# extra gold: SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport GROUP BY T1.AirportCode ORDER BY count(*) LIMIT 1
#
# ...
#
# eval_err_num:580
# medium pred: SELECT arrival , departing date FROM dogs
# medium gold: SELECT date_arrived ,  date_departed FROM Dogs
#
# eval_err_num:581
# medium pred: SELECT arrival , departure FROM dogs
# medium gold: SELECT date_arrived ,  date_departed FROM Dogs
#
# easy pred: SELECT count(*) FROM dogs
# easy gold: SELECT count(DISTINCT dog_id) FROM Treatments
#
# eval_err_num:582
# easy pred: SELECT count(*) FROM dog WHERE treatment = "treatment"
# easy gold: SELECT count(DISTINCT dog_id) FROM Treatments
#
# eval_err_num:583
# easy pred: SELECT count(*) FROM professional AS T1 JOIN treatment AS T2 ON T1.professional = T2.professional
# easy gold: SELECT count(DISTINCT professional_id) FROM Treatments
#
# eval_err_num:584
# easy pred: SELECT count(*) FROM professional AS T1 JOIN dogs AS T2 ON T1.professional = T2.professional
# easy gold: SELECT count(DISTINCT professional_id) FROM Treatments
#
# eval_err_num:585
# medium pred: SELECT T1.street , city , state FROM professionals AS T1 JOIN city AS T2 ON T1.city = T2.city WHERE T2.subtitle 'West'
# medium gold: SELECT role_code ,  street ,  city ,  state FROM professionals WHERE city LIKE '%West%'
#
# eval_err_num:586
# medium pred: SELECT role , street , city , state FROM professionals WHERE city LIKE '%West%'
# medium gold: SELECT role_code ,  street ,  city ,  state FROM professionals WHERE city LIKE '%West%'
#
# eval_err_num:587
# medium pred: SELECT T2.firstname , T2.lastname , T2.email FROM owner AS T1 JOIN state AS T2 ON T1.state = T2.state WHERE T1.subscript LIKE '%North%'
# medium gold: SELECT first_name ,  last_name ,  email_address FROM Owners WHERE state LIKE '%North%'
#
# eval_err_num:588
# medium pred: SELECT T1.first_name , T1.last_name , T1.email FROM owner AS T1 JOIN state AS T2 ON T1.state = T2.state WHERE T2.substring 'North' LIKE '%North%'
# medium gold: SELECT first_name ,  last_name ,  email_address FROM Owners WHERE state LIKE '%North%'
#
# eval_err_num:589
# hard pred: SELECT count(*) FROM dogs WHERE age  (SELECT avg(age) FROM dogs)
# hard gold: SELECT count(*) FROM Dogs WHERE age  <  ( SELECT avg(age) FROM Dogs )
#
# eval_err_num:590
# hard pred: SELECT count(*) FROM dogs WHERE age  (SELECT avg(age) FROM dog)
# hard gold: SELECT count(*) FROM Dogs WHERE age  <  ( SELECT avg(age) FROM Dogs )
#
# eval_err_num:591
# medium pred: SELECT cost_amount FROM Treatments ORDER BY date_of_treatment DESC LIMIT 1
# medium gold: SELECT cost_of_treatment FROM Treatments ORDER BY date_of_treatment DESC LIMIT 1
#
# extra pred: SELECT count(*) FROM dogs EXCEPT SELECT count(*) FROM dogs
# extra gold: SELECT count(*) FROM Dogs WHERE dog_id NOT IN ( SELECT dog_id FROM Treatments )
#
# eval_err_num:592
# extra pred: SELECT count(*) FROM dogs EXCEPT SELECT count(*) FROM dogs WHERE treatment != 'No'
# extra gold: select count(*) from dogs where dog_id not in ( select dog_id from treatments )
#
# eval_err_num:593
# extra pred: SELECT count(*) FROM owner WHERE owner EXCEPT SELECT count(*) FROM dogs
# extra gold: SELECT count(*) FROM Owners WHERE owner_id NOT IN ( SELECT owner_id FROM Dogs )
#
# eval_err_num:594
# extra pred: SELECT count(*) FROM owner WHERE owner NOT IN (SELECT owner FROM dogs)
# extra gold: SELECT count(*) FROM Owners WHERE owner_id NOT IN ( SELECT owner_id FROM Dogs )
#
# extra pred: SELECT count(*) FROM professionals EXCEPT SELECT count(*) FROM dogs
# extra gold: SELECT count(*) FROM Professionals WHERE professional_id NOT IN ( SELECT professional_id FROM Treatments )
#
# extra pred: SELECT count(*) FROM professionals EXCEPT SELECT count(*) FROM dogs
# extra gold: SELECT count(*) FROM Professionals WHERE professional_id NOT IN ( SELECT professional_id FROM Treatments )
#
# eval_err_num:595
# medium pred: SELECT T1.name , T1.age , T1.weight FROM dogs AS T1 JOIN abandoned dogs AS T2 ON T1.dog = T2.dog WHERE T2.weight = 1
# medium gold: SELECT name ,  age ,  weight FROM Dogs WHERE abandoned_yn  =  1
#
# eval_err_num:596
# medium pred: SELECT T1.name , T1.age , T1.weight FROM dogs AS T1 JOIN abandoned AS T2 ON T1.dog = T2.dog WHERE T2.weight = 1 INTERSECT SELECT T1.name , T1.age , T1.weight FROM dogs AS T1 JOIN abandoned AS T2 ON T1.dog = T2.dog WHERE T2.weight = 0
# medium gold: SELECT name ,  age ,  weight FROM Dogs WHERE abandoned_yn  =  1
#
# eval_err_num:597
# easy pred: SELECT age FROM dog ORDER BY age DESC LIMIT 1
# easy gold: SELECT max(age) FROM Dogs
#
# eval_err_num:598
# easy pred: SELECT age FROM dog ORDER BY age DESC LIMIT 1
# easy gold: SELECT max(age) FROM Dogs
#
# eval_err_num:599
# medium pred: SELECT t1.type , t1.amount FROM charge AS t1 JOIN charge AS t2 ON t1.charge = t2.charge GROUP BY t1.charge
# medium gold: SELECT charge_type ,  charge_amount FROM Charges
#
# eval_err_num:600
# medium pred: SELECT charge , amount FROM Charge GROUP BY charge
# medium gold: SELECT charge_type ,  charge_amount FROM Charges
#
# eval_err_num:601
# easy pred: SELECT max(charge) FROM Charge GROUP BY charge ORDER BY count(*) DESC LIMIT 1
# easy gold: SELECT max(charge_amount) FROM Charges
#
# eval_err_num:602
# easy pred: SELECT charge FROM Charge ORDER BY charge DESC LIMIT 1
# easy gold: SELECT max(charge_amount) FROM Charges
#
# eval_err_num:603
# medium pred: SELECT email , cell phone , home phone FROM professionals
# medium gold: SELECT email_address ,  cell_number ,  home_phone FROM professionals
#
# eval_err_num:604
# medium pred: SELECT email , cell phone , home phone FROM professional GROUP BY email
# medium gold: SELECT email_address ,  cell_number ,  home_phone FROM professionals
#
# eval_err_num:605
# medium pred: SELECT DISTINCT breed , size FROM breed
# medium gold: SELECT DISTINCT breed_code ,  size_code FROM dogs
#
# eval_err_num:606
# medium pred: SELECT DISTINCT breed , size FROM dogs
# medium gold: SELECT DISTINCT breed_code ,  size_code FROM dogs
#
# eval_err_num:607
# medium pred: SELECT T2.firstname , T2.description FROM professionals AS T1 JOIN treatment AS T2 ON T1.professional = T2.firstname JOIN treatment AS T3 ON T1.treatment = T3.treatment
# medium gold: SELECT DISTINCT T1.first_name ,  T3.treatment_type_description FROM professionals AS T1 JOIN Treatments AS T2 ON T1.professional_id  =  T2.professional_id JOIN Treatment_types AS T3 ON T2.treatment_type_code  =  T3.treatment_type_code
#
# eval_err_num:608
# medium pred: SELECT T2.firstname , T2.description FROM professional AS T1 JOIN treatment AS T2 ON T1.professional = T2.firstname JOIN treatment AS T3 ON T1.treatment = T3.treatment
# medium gold: SELECT DISTINCT T1.first_name ,  T3.treatment_type_description FROM professionals AS T1 JOIN Treatments AS T2 ON T1.professional_id  =  T2.professional_id JOIN Treatment_types AS T3 ON T2.treatment_type_code  =  T3.treatment_type_code
#
# eval_err_num:609
# easy pred: SELECT Name FROM singer WHERE Citizenship NOT IN (SELECT Singer_ID FROM singer WHERE Citizenship NOT IN (SELECT Singer_ID FROM singer WHERE Citizenship NOT IN (SELECT Singer_ID FROM singer WHERE Citizenship NOT IN (SELECT Singer_ID FROM singer WHERE Citizenship NOT IN (SELECT Singer_ID FROM singer WHERE Citizenship NOT IN (SELECT Singer_ID FROM singer WHERE Citizenship NOT IN (SELECT Singer_ID FROM singer WHERE Citizenship NOT IN (SELECT Singer_ID FROM singer W
# easy gold: SELECT Name FROM singer WHERE Citizenship != "France"
#
# eval_err_num:610
# easy pred: SELECT Name FROM singer WHERE Citizenship NOT IN (SELECT Citizenship FROM singer WHERE Citizenship NOT IN (SELECT Citizenship FROM singer WHERE Citizenship NOT IN (SELECT Citizenship FROM singer WHERE Citizenship NOT IN (SELECT Citizenship NOT IN (SELECT Citizenship NOT IN (SELECT Citizenship NOT IN (SELECT Citizenship NOT IN (SELECT Citizenship NOT IN (SELECT Citizenship NOT IN (SELECT Citizenship NOT IN (SELECT Citizenship NOT IN (SELECT Citizenship NOT IN (SELECT Citizenship NOT IN (SEL
# easy gold: SELECT Name FROM singer WHERE Citizenship != "France"
#
# eval_err_num:611
# medium pred: SELECT T2.Title , T2.Name FROM singer AS T1 JOIN singer AS T2 ON T1.Singer_ID = T2.Singer_ID
# medium gold: SELECT T2.Title ,  T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID
#
# medium pred: SELECT T2.Name , T2.Name FROM singer AS T1 JOIN singer AS T2 ON T1.Singer_ID = T2.Singer_ID
# medium gold: SELECT T2.Title ,  T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID
#
# medium pred: SELECT DISTINCT Name FROM singer WHERE Net_Worth_Millions > 300000
# medium gold: SELECT DISTINCT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID WHERE T2.Sales  >  300000
#
# medium pred: SELECT DISTINCT Name FROM singer WHERE Net_Worth_Millions > 300000
# medium gold: SELECT DISTINCT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID WHERE T2.Sales  >  300000
#
# medium pred: SELECT Name FROM singer GROUP BY Name HAVING COUNT(*) > 1
# medium gold: SELECT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID GROUP BY T1.Name HAVING COUNT(*)  >  1
#
# medium pred: SELECT Name FROM singer GROUP BY Name HAVING COUNT(*) > 1
# medium gold: SELECT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID GROUP BY T1.Name HAVING COUNT(*)  >  1
#
# medium pred: SELECT T2.Name , sum(T2.Net_Worth_Millions) FROM singer AS T1 JOIN singer AS T2 ON T1.Singer_ID = T2.Singer_ID
# medium gold: SELECT T1.Name ,  sum(T2.Sales) FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID GROUP BY T1.Name
#
# medium pred: SELECT T1.Name , COUNT(*) FROM singer AS T1 JOIN singer AS T2 ON T1.Singer_ID = T2.Singer_ID GROUP BY T1.Name
# medium gold: SELECT T1.Name ,  sum(T2.Sales) FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID GROUP BY T1.Name
#
# hard pred: SELECT Name FROM singer WHERE Singer_ID NOT IN (SELECT Singer_ID FROM singer)
# hard gold: SELECT Name FROM singer WHERE Singer_ID NOT IN (SELECT Singer_ID FROM song)
#
# hard pred: SELECT Name FROM singer WHERE Singer_ID NOT IN (SELECT Singer_ID FROM singer)
# hard gold: SELECT Name FROM singer WHERE Singer_ID NOT IN (SELECT Singer_ID FROM song)
#
# eval_err_num:612
# hard pred: SELECT Citizenship FROM singer WHERE Birth_Year  1945 INTERSECT SELECT Citizenship FROM singer WHERE Birth_Year > 1955
# hard gold: SELECT Citizenship FROM singer WHERE Birth_Year  <  1945 INTERSECT SELECT Citizenship FROM singer WHERE Birth_Year  >  1955
#
# eval_err_num:613
# hard pred: SELECT Citizenship FROM singer WHERE Birth_Year  1945 INTERSECT SELECT Citizenship FROM singer WHERE Birth_Year > 1955
# hard gold: SELECT Citizenship FROM singer WHERE Birth_Year  <  1945 INTERSECT SELECT Citizenship FROM singer WHERE Birth_Year  >  1955
#
# eval_err_num:614
# easy pred: SELECT count(*) FROM Features
# easy gold: SELECT count(*) FROM Other_Available_Features
#
# eval_err_num:615
# medium pred: SELECT Feature_Type FROM Feature AS t1 JOIN AirCon AS t2 ON t1.Feature_Type = t2.Feature_Type WHERE t2.Feature_Name = "AirCon"
# medium gold: SELECT T2.feature_type_name FROM Other_Available_Features AS T1 JOIN Ref_Feature_Types AS T2 ON T1.feature_type_code  =  T2.feature_type_code WHERE T1.feature_name  =  "AirCon"
#
# eval_err_num:616
# medium pred: SELECT T2.property_type FROM properties AS T1 JOIN properties AS T2 ON T1.property = T2.property WHERE T1.code = 'CODE'
# medium gold: SELECT T2.property_type_description FROM Properties AS T1 JOIN Ref_Property_Types AS T2 ON T1.property_type_code  =  T2.property_type_code GROUP BY T1.property_type_code
#
# eval_err_num:617
# hard pred: SELECT T1.name FROM properties AS T1 JOIN apartments AS T2 ON T1.properties = T2.properties WHERE T2.room > 1
# hard gold: SELECT property_name FROM Properties WHERE property_type_code  =  "House" UNION SELECT property_name FROM Properties WHERE property_type_code  =  "Apartment" AND room_count  >  1
#
#                      easy                 medium               hard                 extra                all
# count                248                  446                  174                  166                  1034
#
# ====================== EXACT MATCHING ACCURACY =====================
# exact match          0.448                0.186                0.132                0.036                0.216
#
# ---------------------PARTIAL MATCHING ACCURACY----------------------
# select               0.920                0.797                0.849                0.841                0.849
# select(no AGG)       0.949                0.813                0.849                0.841                0.866
# where                0.769                0.662                0.481                0.357                0.639
# where(no OP)         0.788                0.662                0.704                0.357                0.684
# group(no Having)     0.750                0.698                0.727                0.741                0.717
# group                0.750                0.667                0.727                0.667                0.683
# order                1.000                0.667                0.720                0.667                0.722
# and/or               1.000                0.935                0.908                0.880                0.937
# IUEN                 0.000                0.000                0.000                0.222                0.182
# keywords             1.000                0.885                0.830                0.568                0.861
# ---------------------- PARTIAL MATCHING RECALL ----------------------
# select               0.512                0.325                0.259                0.223                0.342
# select(no AGG)       0.528                0.332                0.259                0.223                0.349
# where                0.370                0.236                0.138                0.053                0.211
# where(no OP)         0.380                0.236                0.202                0.053                0.226
# group(no Having)     0.300                0.331                0.410                0.253                0.317
# group                0.300                0.316                0.410                0.228                0.303
# order                0.682                0.427                0.327                0.228                0.359
# and/or               1.000                1.000                1.000                0.986                0.998
# IUEN                 0.000                0.000                0.000                0.059                0.026
# keywords             0.500                0.386                0.253                0.151                0.334
# ---------------------- PARTIAL MATCHING F1 --------------------------
# select               0.658                0.462                0.396                0.352                0.488
# select(no AGG)       0.679                0.471                0.396                0.352                0.498
# where                0.500                0.348                0.215                0.093                0.318
# where(no OP)         0.513                0.348                0.314                0.093                0.340
# group(no Having)     0.429                0.449                0.525                0.377                0.440
# group                0.429                0.429                0.525                0.340                0.419
# order                0.811                0.520                0.450                0.340                0.480
# and/or               1.000                0.966                0.952                0.930                0.967
# IUEN                 1.000                1.000                1.000                0.093                0.046
# keywords             0.667                0.538                0.388                0.238                0.481
